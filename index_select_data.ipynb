# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. 导入数据集
# 读取新能源数据集，原始数据集df使用编号作为索引，我们再创建一个使用brand作为index的数据集df_brand_index

# %%
df = pd.read_csv('NEV_sales.csv')
df.head(2)
# Out:
#   brand  2019-12  2019-11  2019-10  2019-09  2019-08  2019-07  2019-06  \
# 0    北京  36197.0   7005.0   8591.0  10000.0  10696.0  12503.0  26039.0
# 1   比亚迪  10717.0  10675.0  12042.0  13048.0  16100.0  16010.0  25826.0
#
#    2019-05  2019-04  2019-03  2019-02  2019-01  2018-12    2019累计
# 0   8969.0   4945.0  17690.0   2866.0   4258.0  27822.0  149759.0
# 1  20945.0  22735.0  29219.0  14005.0  31870.0  35752.0  223192.0

# %%
df_brand_index = df.set_index('brand')
df_brand_index.tail(2)
# Out:
#         2019-12  2019-11  2019-10  2019-09  2019-08  2019-07   2019-06  \
# brand
# 奔驰          NaN      NaN      NaN      NaN      NaN      NaN       NaN
# 总计     132858.0  72795.0  62768.0  64701.0  70432.0  67816.0  131133.0
#
#        2019-05  2019-04   2019-03  2019-02  2019-01   2018-12     2019累计
# brand
# 奔驰         NaN      NaN       NaN      NaN      NaN       NaN        NaN
# 总计     96753.0  91397.0  106639.0  50842.0  90212.0  133645.0  1038346.0

# %%
df_brand_index.shape, df.shape
# Out:
# ((77, 14), (77, 15))

# %%
df_brand_index.describe()
# Out:
#              2019-12       2019-11       2019-10       2019-09       2019-08  \
# count      40.000000     38.000000     37.000000     38.000000     38.000000
# mean     6642.900000   3831.315789   3392.864865   3405.315789   3706.947368
# std     21358.363466  11807.801860  10339.247663  10571.305128  11603.860126
# min         1.000000     10.000000      6.000000      6.000000      1.000000
# 25%       198.500000    201.000000    203.000000    157.750000    112.000000
# 50%      1500.500000   1027.500000    969.000000    505.000000    447.500000
# 75%      4047.250000   2361.000000   2148.000000   2404.750000   2700.500000
# max    132858.000000  72795.000000  62768.000000  64701.000000  70432.000000
#
#             2019-07        2019-06       2019-05       2019-04        2019-03  \
# count     38.000000      44.000000     45.000000     41.000000      41.000000
# mean    3569.263158    5960.590909   4300.133333   4458.390244    5201.902439
# std    11203.349807   20112.219831  14553.902002  14461.270293   17076.162294
# min        2.000000       1.000000      1.000000      6.000000       9.000000
# 25%       57.000000     254.750000    137.000000    225.000000     239.000000
# 50%      624.000000    1041.000000   1068.000000    991.000000     961.000000
# 75%     2425.750000    3540.250000   2822.000000   2566.000000    2478.000000
# max    67816.000000  131133.000000  96753.000000  91397.000000  106639.000000
#
#             2019-02       2019-01        2018-12        2019累计
# count     45.000000     42.000000      34.000000  5.900000e+01
# mean    2259.644444   4295.809524    7861.470588  3.519817e+04
# std     7754.008547  14503.124026   23425.312214  1.377841e+05
# min        1.000000      3.000000       9.000000  1.000000e+00
# 25%      106.000000    172.750000     632.500000  1.025500e+03
# 50%      340.000000    493.500000    1688.000000  2.867000e+03
# 75%     1269.000000   2796.750000    4579.250000  1.872550e+04
# max    50842.000000  90212.000000  133645.000000  1.038346e+06

# %%
df_brand_index.dtypes
# Out:
# 2019-12    float64
# 2019-11    float64
# 2019-10    float64
# 2019-09    float64
# 2019-08    float64
# 2019-07    float64
# 2019-06    float64
# 2019-05    float64
# 2019-04    float64
# 2019-03    float64
# 2019-02    float64
# 2019-01    float64
# 2018-12    float64
# 2019累计     float64
# dtype: object

# %% [markdown]
# # 2. 列选择

# %%
sr_brand_index = df_brand_index['2019-11']
sr_brand_index.head(2)
# Out:
# brand
# 北京      7005.0
# 比亚迪    10675.0
# Name: 2019-11, dtype: float64

# %%
df_brand_index[['2019-12', '2019-11']].head(2)
# Out:
#        2019-12  2019-11
# brand
# 北京     36197.0   7005.0
# 比亚迪    10717.0  10675.0

# %% [markdown]
# # 3. 行选择
# 采用编号作为索引的数据集使用loc（标签定位）

# %%
df.loc[0:4]
# Out:
#   brand  2019-12  2019-11  2019-10  2019-09  2019-08  2019-07  2019-06  \
# 0    北京  36197.0   7005.0   8591.0  10000.0  10696.0  12503.0  26039.0
# 1   比亚迪  10717.0  10675.0  12042.0  13048.0  16100.0  16010.0  25826.0
# 2    传祺   8970.0   6046.0   4541.0   4010.0   3816.0   3406.0   3073.0
# 3    奔腾   8735.0   2380.0    356.0    372.0    125.0      NaN      NaN
# 4    宝骏   8352.0   9809.0   4636.0   5353.0   8698.0   6328.0   4556.0
#
#    2019-05  2019-04  2019-03  2019-02  2019-01  2018-12    2019累计
# 0   8969.0   4945.0  17690.0   2866.0   4258.0  27822.0  149759.0
# 1  20945.0  22735.0  29219.0  14005.0  31870.0  35752.0  223192.0
# 2   2014.0   1903.0   1654.0    838.0    370.0   3252.0   40641.0
# 3     90.0      NaN      NaN      NaN      NaN      9.0   12058.0
# 4    546.0   1488.0    961.0   1011.0   8312.0   4692.0   60050.0

# %% [markdown]
# 采用编号作为索引的数据集使用iloc（整数编号定位） - 跟python内置数据结构list类似，[0,4)

# %%
df.iloc[0:4]
# Out:
#   brand  2019-12  2019-11  2019-10  2019-09  2019-08  2019-07  2019-06  \
# 0    北京  36197.0   7005.0   8591.0  10000.0  10696.0  12503.0  26039.0
# 1   比亚迪  10717.0  10675.0  12042.0  13048.0  16100.0  16010.0  25826.0
# 2    传祺   8970.0   6046.0   4541.0   4010.0   3816.0   3406.0   3073.0
# 3    奔腾   8735.0   2380.0    356.0    372.0    125.0      NaN      NaN
#
#    2019-05  2019-04  2019-03  2019-02  2019-01  2018-12    2019累计
# 0   8969.0   4945.0  17690.0   2866.0   4258.0  27822.0  149759.0
# 1  20945.0  22735.0  29219.0  14005.0  31870.0  35752.0  223192.0
# 2   2014.0   1903.0   1654.0    838.0    370.0   3252.0   40641.0
# 3     90.0      NaN      NaN      NaN      NaN      9.0   12058.0

# %% [markdown]
# 使用brand作为索引的数据集采用loc（标签定位）

# %%
df_brand_index.loc['北京':'宝骏']
# Out:
#        2019-12  2019-11  2019-10  2019-09  2019-08  2019-07  2019-06  2019-05  \
# brand
# 北京     36197.0   7005.0   8591.0  10000.0  10696.0  12503.0  26039.0   8969.0
# 比亚迪    10717.0  10675.0  12042.0  13048.0  16100.0  16010.0  25826.0  20945.0
# 传祺      8970.0   6046.0   4541.0   4010.0   3816.0   3406.0   3073.0   2014.0
# 奔腾      8735.0   2380.0    356.0    372.0    125.0      NaN      NaN     90.0
# 宝骏      8352.0   9809.0   4636.0   5353.0   8698.0   6328.0   4556.0    546.0
#
#        2019-04  2019-03  2019-02  2019-01  2018-12    2019累计
# brand
# 北京      4945.0  17690.0   2866.0   4258.0  27822.0  149759.0
# 比亚迪    22735.0  29219.0  14005.0  31870.0  35752.0  223192.0
# 传祺      1903.0   1654.0    838.0    370.0   3252.0   40641.0
# 奔腾         NaN      NaN      NaN      NaN      9.0   12058.0
# 宝骏      1488.0    961.0   1011.0   8312.0   4692.0   60050.0

# %%
df_brand_index.loc[0:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-06f3d2934cea> in <module>
# ----> 1 df_brand_index.loc[0:4]
#
# ~/venvs/venv_dt_sci/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~/venvs/venv_dt_sci/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1865         if isinstance(key, slice):
#    1866             self._validate_key(key, axis)
# -> 1867             return self._get_slice_axis(key, axis=axis)
#    1868         elif com.is_bool_indexer(key):
#    1869             return self._getbool_axis(key, axis=axis)
#
# ~/venvs/venv_dt_sci/lib/python3.7/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1531         labels = obj._get_axis(axis)
#    1532         indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop,
# -> 1533                                        slice_obj.step, kind=self.name)
#    1534
#    1535         if isinstance(indexer, slice):
#
# ~/venvs/venv_dt_sci/lib/python3.7/site-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    4670         """
#    4671         start_slice, end_slice = self.slice_locs(start, end, step=step,
# -> 4672                                                  kind=kind)
#    4673
#    4674         # return a slice
#
# ~/venvs/venv_dt_sci/lib/python3.7/site-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    4869         start_slice = None
#    4870         if start is not None:
# -> 4871             start_slice = self.get_slice_bound(start, 'left', kind)
#    4872         if start_slice is None:
#    4873             start_slice = 0
#
# ~/venvs/venv_dt_sci/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    4795         # For datetime indices label may be a string that has to be converted
#    4796         # to datetime boundary according to its resolution.
# -> 4797         label = self._maybe_cast_slice_bound(label, side, kind)
#    4798
#    4799         # we need to look up the label
#
# ~/venvs/venv_dt_sci/lib/python3.7/site-packages/pandas/core/indexes/base.py in _maybe_cast_slice_bound(self, label, side, kind)
#    4747         # this is rejected (generally .loc gets you here)
#    4748         elif is_integer(label):
# -> 4749             self._invalid_indexer('slice', label)
#    4750
#    4751         return label
#
# ~/venvs/venv_dt_sci/lib/python3.7/site-packages/pandas/core/indexes/base.py in _invalid_indexer(self, form, key)
#    3064                         "indexers [{key}] of {kind}".format(
#    3065                             form=form, klass=type(self), key=key,
# -> 3066                             kind=type(key)))
#    3067
#    3068     # --------------------------------------------------------------------
#
# TypeError: cannot do slice indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [0] of <class 'int'>

# %% [markdown]
# 使用brand作为索引的数据集采用iloc（标签定位）

# %%
df_brand_index.iloc[0:4]
# Out:
#        2019-12  2019-11  2019-10  2019-09  2019-08  2019-07  2019-06  2019-05  \
# brand
# 北京     36197.0   7005.0   8591.0  10000.0  10696.0  12503.0  26039.0   8969.0
# 比亚迪    10717.0  10675.0  12042.0  13048.0  16100.0  16010.0  25826.0  20945.0
# 传祺      8970.0   6046.0   4541.0   4010.0   3816.0   3406.0   3073.0   2014.0
# 奔腾      8735.0   2380.0    356.0    372.0    125.0      NaN      NaN     90.0
#
#        2019-04  2019-03  2019-02  2019-01  2018-12    2019累计
# brand
# 北京      4945.0  17690.0   2866.0   4258.0  27822.0  149759.0
# 比亚迪    22735.0  29219.0  14005.0  31870.0  35752.0  223192.0
# 传祺      1903.0   1654.0    838.0    370.0   3252.0   40641.0
# 奔腾         NaN      NaN      NaN      NaN      9.0   12058.0

# %% [markdown]
# # 4. 行+列索引，找到元素

# %%
df_brand_index.loc['北京', '2019-11']
# Out:
# 7005.0

# %%
df_brand_index.iloc[0, 1] # 1st column is 2019-11 in df_brand_index
# Out:
# 7005.0

# %%
df_brand_index.loc['北京':'宝骏', '2019-12':'2019-10']
# Out:
#        2019-12  2019-11  2019-10
# brand
# 北京     36197.0   7005.0   8591.0
# 比亚迪    10717.0  10675.0  12042.0
# 传祺      8970.0   6046.0   4541.0
# 奔腾      8735.0   2380.0    356.0
# 宝骏      8352.0   9809.0   4636.0

# %%
df_brand_index.iloc[0:5, 0:3]
# Out:
#        2019-12  2019-11  2019-10
# brand
# 北京     36197.0   7005.0   8591.0
# 比亚迪    10717.0  10675.0  12042.0
# 传祺      8970.0   6046.0   4541.0
# 奔腾      8735.0   2380.0    356.0
# 宝骏      8352.0   9809.0   4636.0

# %% [markdown]
# # 5. 条件选择
# 条件必须使用括号括起来

# %%
df_brand_index[(df_brand_index['2019-12'] > 3000) & (df_brand_index['2019-11'] > 3000)]
# Out:
#         2019-12  2019-11  2019-10  2019-09  2019-08  2019-07   2019-06  \
# brand
# 北京      36197.0   7005.0   8591.0  10000.0  10696.0  12503.0   26039.0
# 比亚迪     10717.0  10675.0  12042.0  13048.0  16100.0  16010.0   25826.0
# 传祺       8970.0   6046.0   4541.0   4010.0   3816.0   3406.0    3073.0
# 宝骏       8352.0   9809.0   4636.0   5353.0   8698.0   6328.0    4556.0
# 名爵       4951.0   3756.0   2734.0   2008.0   1898.0    696.0     356.0
# 总计     132858.0  72795.0  62768.0  64701.0  70432.0  67816.0  131133.0
#
#        2019-05  2019-04   2019-03  2019-02  2019-01   2018-12     2019累计
# brand
# 北京      8969.0   4945.0   17690.0   2866.0   4258.0   27822.0   149759.0
# 比亚迪    20945.0  22735.0   29219.0  14005.0  31870.0   35752.0   223192.0
# 传祺      2014.0   1903.0    1654.0    838.0    370.0    3252.0    40641.0
# 宝骏       546.0   1488.0     961.0   1011.0   8312.0    4692.0    60050.0
# 名爵      1570.0    733.0     559.0    174.0    157.0      58.0    19592.0
# 总计     96753.0  91397.0  106639.0  50842.0  90212.0  133645.0  1038346.0

# %% [markdown]
# # 6. 查找元素位置

# %%
df_brand_index[df_brand_index['2019-11']==6046].index
# Out:
# Index(['传祺'], dtype='object', name='brand')

# %%
idx = np.where(df_brand_index.to_numpy()==6046)[0][0]
col = np.where(df_brand_index.to_numpy()==6046)[1][0]
idx, col
# Out:
# (2, 1)

# %%
df_brand_index.index[2], df_brand_index.columns[1]
# Out:
# ('传祺', '2019-11')
